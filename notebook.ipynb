# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import random as r

# %%
pearl_prob = 20/423

# %%
def pearl_trade():
    a = r.uniform(0, 1)
    print(a)
    return a<pearl_prob

# %%
print(pearl_trade())

# %%
print(pearl_trade())
